# %% [markdown]
# ## ESPN球員球員效率值
#
# [http://insider.espn.com/nba/hollinger/statistics/_/page/1](http://insider.espn.com/nba/hollinger/statistics/_/page/1)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import random

url = 'http://insider.espn.com/nba/hollinger/statistics/_/page/'

try:
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    chrome = webdriver.Chrome(options=options,
                             executable_path='D:\\ANACONDA\\chromedriver-win64\\chromedriver.exe')
    chrome.set_page_load_timeout(10)
    i = 1
    for i in range(i, 9):
        _url = url + str(i)
        print(_url)
        chrome.get(_url)
        soup = BeautifulSoup(chrome.page_source, 'html5lib')
        trs = soup.find('tbody').find_all('tr')
        for tr in trs:
            tds = [td for td in tr.children]
            rk = tds[0].text.strip()
            if rk =='RK' or len(tds)<2:
                continue
            name = tds[1].text
            per = tds[11].text
            print('%s :%s' % (name, per))
        wait = random.randint(2,6)
        print('wait time : %d' % wait)
        time.sleep(wait)
    
    
finally:
    chrome.quit()
# Out:
# http://insider.espn.com/nba/hollinger/statistics/_/page/1
# Nikola Jokic, DEN :31.78
# Joel Embiid, PHI :31.69
# Giannis Antetokounmpo, MIL :29.29
# Luka Doncic, DAL :28.99
# Anthony Davis, LAL :28.00
# Jimmy Butler, MIA :27.82
# Shai Gilgeous-Alexander, OKC :27.43
# Damian Lillard, POR :26.96
# Kevin Durant, BKN/PHX :26.14
# Zion Williamson, NO :25.43
# Stephen Curry, GS :24.36
# Kawhi Leonard, LAC :24.13
# LeBron James, LAL :24.11
# Jayson Tatum, BOS :23.92
# Tyrese Haliburton, IND :23.79
# Domantas Sabonis, SAC :23.66
# Ja Morant, MEM :23.52
# Kristaps Porzingis, WSH :23.28
# Donovan Mitchell, CLE :23.13
# Kyrie Irving, BKN/DAL :22.65
# Lauri Markkanen, UTAH :22.32
# Clint Capela, ATL :22.25
# Devin Booker, PHX :22.21
# Trae Young, ATL :22.15
# De'Aaron Fox, SAC :21.98
# Jaren Jackson Jr., MEM :21.82
# James Harden, PHI :21.78
# Walker Kessler, UTAH :21.72
# Jalen Brunson, NY :21.38
# Jakob Poeltl, SA/TOR :21.16
# Nic Claxton, BKN :20.99
# Andre Drummond, CHI :20.96
# Christian Wood, DAL :20.83
# DeMar DeRozan, CHI :20.75
# Julius Randle, NY :20.55
# Pascal Siakam, TOR :20.52
# Bam Adebayo, MIA :20.26
# Myles Turner, IND :20.25
# Brandon Clarke, MEM :20.18
# Deandre Ayton, PHX :20.09
# Jarrett Allen, CLE :20.09
# Robert Williams III, BOS :20.00
# Mark Williams, CHA :19.98
# Bradley Beal, WSH :19.95
# Daniel Gafford, WSH :19.92
# Alperen Sengun, HOU :19.87
# Thomas Bryant, LAL/DEN :19.85
# Mason Plumlee, CHA/LAC :19.78
# Paul George, LAC :19.75
# Aaron Gordon, DEN :19.67
# wait time : 5
# http://insider.espn.com/nba/hollinger/statistics/_/page/2
# Onyeka Okongwu, ATL :19.53
# Jonas Valanciunas, NO :19.46
# Jrue Holiday, MIL :19.43
# Brandon Ingram, NO :19.40
# Desmond Bane, MEM :19.33
# Jaylen Brown, BOS :19.29
# Paul Reed, PHI :19.29
# Nikola Vucevic, CHI :19.27
# Kris Dunn, UTAH :19.24
# Zach LaVine, CHI :19.23
# Mitchell Robinson, NY :19.06
# Rudy Gobert, MIN :19.06
# Darius Garland, CLE :19.02
# Karl-Anthony Towns, MIN :18.98
# Charles Bassey, SA :18.96
# Naz Reid, MIN :18.72
# Brook Lopez, MIL :18.61
# Nick Richards, CHA :18.42
# Malcolm Brogdon, BOS :18.34
# Chris Boucher, TOR :18.20
# Jamal Murray, DEN :18.14
# Evan Mobley, CLE :18.07
# LaMelo Ball, CHA :18.06
# Bobby Portis, MIL :18.00
# Day'Ron Sharpe, BKN :17.94
# Chris Paul, PHX :17.91
# Kevon Looney, GS :17.91
# Montrezl Harrell, PHI :17.77
# Isaiah Jackson, IND :17.67
# Steven Adams, MEM :17.66
# Moritz Wagner, ORL :17.59
# Bojan Bogdanovic, DET :17.55
# Anthony Edwards, MIN :17.54
# Khris Middleton, MIL :17.53
# Jusuf Nurkic, POR :17.49
# Wendell Carter Jr., ORL :17.48
# Jalen Duren, DET :17.46
# Chimezie Metu, SAC :17.45
# Xavier Tillman, MEM :17.40
# Marvin Bagley III, DET :17.34
# Norman Powell, LAC :17.28
# Josh Giddey, OKC :17.26
# Cameron Johnson, PHX/BKN :17.25
# Tyrese Maxey, PHI :17.21
# Dejounte Murray, ATL :17.19
# Fred VanVleet, TOR :17.16
# Mikal Bridges, PHX/BKN :17.02
# T.J. McConnell, IND :16.97
# Michael Porter Jr., DEN :16.97
# Ivica Zubac, LAC :16.89
# wait time : 5
# http://insider.espn.com/nba/hollinger/statistics/_/page/3
# Luke Kornet, BOS :16.88
# Markelle Fultz, ORL :16.81
# Malik Monk, SAC :16.72
# Alec Burks, DET :16.62
# Jock Landale, PHX :16.60
# Zach Collins, SA :16.53
# D'Angelo Russell, MIN/LAL :16.49
# Immanuel Quickley, NY :16.46
# Delon Wright, WSH :16.39
# Kevin Porter Jr., HOU :16.37
# Drew Eubanks, POR :16.37
# Russell Westbrook, LAL/LAC :16.23
# Spencer Dinwiddie, DAL/BKN :16.20
# Jerami Grant, POR :16.20
# Larry Nance Jr., NO :16.16
# Tyus Jones, MEM :16.15
# Tre Jones, SA :16.14
# Cole Anthony, ORL :16.10
# Franz Wagner, ORL :16.10
# Collin Sexton, UTAH :16.09
# Jalen Smith, IND :16.07
# Hamidou Diallo, DET :15.88
# Mo Bamba, ORL/LAL :15.88
# CJ McCollum, NO :15.81
# James Wiseman, GS/DET :15.75
# Jalen Williams, OKC :15.74
# Dwight Powell, DAL :15.69
# Scottie Barnes, TOR :15.68
# JaMychal Green, GS :15.67
# Devin Vassell, SA :15.63
# Kenyon Martin Jr., HOU :15.59
# Buddy Hield, IND :15.59
# Derrick White, BOS :15.55
# Tyler Herro, MIA :15.49
# Keldon Johnson, SA :15.48
# Tari Eason, HOU :15.39
# Kevin Huerter, SAC :15.38
# Trey Murphy III, NO :15.31
# Precious Achiuwa, TOR :15.31
# Jarred Vanderbilt, UTAH/LAL :15.22
# Gary Trent Jr., TOR :15.11
# Bones Hyland, DEN/LAC :15.10
# Monte Morris, WSH :15.09
# Paolo Banchero, ORL :15.08
# Austin Reaves, LAL :15.06
# Keita Bates-Diop, SA :15.01
# Kelly Oubre Jr., CHA :15.00
# Tobias Harris, PHI :14.98
# Jordan Goodwin, WSH :14.96
# Kyle Anderson, MIN :14.95
# wait time : 6
# http://insider.espn.com/nba/hollinger/statistics/_/page/4
# Anfernee Simons, POR :14.94
# Andrew Wiggins, GS :14.88
# Cam Thomas, BKN :14.87
# Klay Thompson, GS :14.87
# Jordan Clarkson, UTAH :14.87
# Mike Conley, UTAH/MIN :14.86
# DeAndre Jordan, DEN :14.83
# Terry Rozier, CHA :14.81
# Jordan Poole, GS :14.75
# Jaden Hardy, DAL :14.73
# O.G. Anunoby, TOR :14.72
# Saddiq Bey, DET/ATL :14.71
# Jalen Green, HOU :14.71
# Isaiah Joe, OKC :14.61
# Bol Bol, ORL :14.55
# Bismack Biyombo, PHX :14.55
# Wenyen Gabriel, LAL :14.53
# Kelly Olynyk, UTAH :14.52
# Kenrich Williams, OKC :14.51
# Kyle Kuzma, WSH :14.46
# Trey Lyles, SAC :14.34
# Isaiah Hartenstein, NY :14.32
# Robert Covington, LAC :14.31
# Bogdan Bogdanovic, ATL :14.29
# Jalen Johnson, ATL :14.24
# Harrison Barnes, SAC :14.23
# Thaddeus Young, TOR :14.20
# Josh Hart, POR/NY :14.18
# Edmond Sumner, BKN :14.14
# Santi Aldama, MEM :14.06
# Al Horford, BOS :13.96
# Jericho Sims, NY :13.88
# Jaxson Hayes, NO :13.88
# Derrick Jones Jr., CHI :13.87
# Jaylen Nowell, MIN :13.84
# Talen Horton-Tucker, UTAH :13.82
# John Collins, ATL :13.74
# John Wall, LAC :13.74
# Obi Toppin, NY :13.70
# T.J. Warren, BKN/PHX :13.70
# Trendon Watford, POR :13.69
# Dario Saric, PHX/OKC :13.66
# Gordon Hayward, CHA :13.64
# Sandro Mamukelashvili, MIL/SA :13.57
# Ben Simmons, BKN :13.56
# Aleksej Pokusevski, OKC :13.54
# Terance Mann, LAC :13.48
# Jonathan Kuminga, GS :13.45
# Bruce Brown, DEN :13.42
# Josh Okogie, PHX :13.39
# wait time : 5
# http://insider.espn.com/nba/hollinger/statistics/_/page/5
# Cameron Payne, PHX :13.38
# Rui Hachimura, WSH/LAL :13.29
# Kevin Love, CLE/MIA :13.27
# Bennedict Mathurin, IND :13.25
# Isaiah Stewart, DET :13.24
# Blake Griffin, BOS :13.23
# Darius Bazley, OKC/PHX :13.23
# Mike Muscala, OKC/BOS :13.16
# Luke Kennard, LAC/MEM :13.08
# Jeremiah Robinson-Earl, OKC :13.06
# P.J. Washington, CHA :13.03
# Terence Davis, SAC :13.02
# RJ Barrett, NY :13.01
# Usman Garuba, HOU :12.98
# Donte DiVincenzo, GS :12.97
# Ty Jerome, GS :12.89
# De'Anthony Melton, PHI :12.85
# Shake Milton, PHI :12.81
# Sam Hauser, BOS :12.81
# Kyle Lowry, MIA :12.69
# Raul Neto, CLE :12.68
# AJ Griffin, ATL :12.68
# Zeke Nnaji, DEN :12.67
# Jalen Suggs, ORL :12.63
# Devonte' Graham, NO/SA :12.61
# Coby White, CHI :12.57
# Caris LeVert, CLE :12.57
# Keegan Murray, SAC :12.46
# Josh Richardson, SA/NO :12.46
# Seth Curry, BKN :12.41
# Grayson Allen, MIL :12.40
# Jordan Nwora, MIL/IND :12.36
# Jae'Sean Tate, HOU :12.34
# Lonnie Walker IV, LAL :12.31
# Draymond Green, GS :12.31
# Aaron Wiggins, OKC :12.31
# Tim Hardaway Jr., DAL :12.22
# Marcus Smart, BOS :12.22
# Yuta Watanabe, BKN :12.22
# Jaden Ivey, DET :12.20
# Herbert Jones, NO :12.19
# Cory Joseph, DET :12.15
# Jaden McDaniels, MIN :12.15
# Cedi Osman, CLE :12.15
# Jose Alvarado, NO :11.97
# Eric Gordon, HOU/LAC :11.94
# Jalen McDaniels, CHA/PHI :11.92
# Lindy Waters III, OKC :11.90
# Quentin Grimes, NY :11.86
# Jordan McLaughlin, MIN :11.86
# wait time : 6
# http://insider.espn.com/nba/hollinger/statistics/_/page/6
# Torrey Craig, PHX :11.74
# Nickeil Alexander-Walker, UTAH/MIN :11.73
# Dennis Smith Jr., CHA :11.71
# Theo Maledon, CHA :11.69
# Josh Christopher, HOU :11.67
# Shaedon Sharpe, POR :11.64
# Corey Kispert, WSH :11.61
# Kentavious Caldwell-Pope, DEN :11.60
# De'Andre Hunter, ATL :11.59
# Dennis Schroder, LAL :11.59
# Alex Caruso, CHI :11.55
# Jeremy Sochan, SA :11.52
# Naji Marshall, NO :11.51
# Christian Koloko, TOR :11.47
# Caleb Martin, MIA :11.46
# Luguentz Dort, OKC :11.44
# Patrick Williams, CHI :11.35
# Jabari Smith Jr., HOU :11.33
# Jaylin Williams, OKC :11.33
# Josh Green, DAL :11.33
# Deni Avdija, WSH :11.29
# Doug McDermott, SA :11.28
# Kevin Knox II, DET/POR :11.24
# Kendrick Nunn, LAL/WSH :11.24
# Anthony Gill, WSH :11.16
# Vlatko Cancar, DEN :11.10
# Jeff Green, DEN :11.10
# Nicolas Batum, LAC :11.06
# Malik Beasley, UTAH/LAL :11.04
# Eugene Omoruyi, OKC/DET :11.02
# Georges Niang, PHI :11.01
# Anthony Lamb, GS :10.99
# Landry Shamet, PHX :10.97
# Jevon Carter, BOS/MIL :10.95
# R.J. Hampton, ORL/DET :10.94
# John Konchar, MEM :10.92
# Kai Jones, CHA :10.90
# Max Strus, MIA :10.89
# Damion Lee, PHX :10.85
# Isaac Okoro, CLE :10.84
# Joe Ingles, MIL :10.82
# Patty Mills, BKN :10.76
# Rodney McGruder, DET :10.76
# George Hill, MIL/IND :10.74
# Joe Harris, BKN :10.72
# Oshae Brissett, IND :10.72
# Cam Reddish, NY/POR :10.71
# Victor Oladipo, MIA :10.68
# Marcus Morris Sr., LAC :10.60
# Gary Harris, ORL :10.57
# wait time : 2
# http://insider.espn.com/nba/hollinger/statistics/_/page/7
# Matisse Thybulle, PHI/POR :10.57
# Aaron Nesmith, IND :10.57
# Romeo Langford, SA :10.52
# Ricky Rubio, CLE :10.48
# Goran Dragic, CHI/MIL :10.43
# Moses Moody, GS :10.43
# Grant Williams, BOS :10.41
# Payton Pritchard, BOS :10.39
# Nassir Little, POR :10.35
# Christian Braun, DEN :10.35
# Terrence Ross, ORL/PHX :10.33
# Killian Hayes, DET :10.29
# Ayo Dosunmu, CHI :10.28
# Reggie Jackson, LAC/DEN :10.15
# Tre Mann, OKC :10.13
# Pat Connaughton, MIL :10.10
# Will Barton, WSH/TOR :10.08
# Andrew Nembhard, IND :10.06
# Taurean Prince, MIN :10.06
# Garrison Mathews, HOU/ATL :9.80
# Jabari Walker, POR :9.75
# Troy Brown Jr., LAL :9.66
# Lamar Stevens, CLE :9.63
# Malaki Branham, SA :9.62
# Ochai Agbaji, UTAH :9.61
# Dillon Brooks, MEM :9.55
# Aaron Holiday, ATL :9.52
# Davion Mitchell, SAC :9.50
# Danuel House Jr., PHI :9.45
# Ousmane Dieng, OKC :9.44
# Justise Winslow, POR :9.35
# Royce O'Neale, BKN :9.33
# Ish Wainright, PHX :9.33
# Dorian Finney-Smith, DAL/BKN :9.30
# Chuma Okeke, ORL :9.22
# Rudy Gay, UTAH :9.10
# Gabe Vincent, MIA :9.08
# Patrick Beverley, LAL/CHI :8.98
# David Roddy, MEM :8.87
# Dyson Daniels, NO :8.86
# Maxi Kleber, DAL :8.81
# Malachi Flynn, TOR :8.75
# Chris Duarte, IND :8.74
# Haywood Highsmith, MIA :8.59
# Dean Wade, CLE :8.56
# Miles McBride, NY :8.47
# Isaiah Livers, DET :8.44
# MarJon Beauchamp, MIL :8.34
# Simone Fontecchio, UTAH :8.09
# Duncan Robinson, MIA :7.90
# wait time : 3
# http://insider.espn.com/nba/hollinger/statistics/_/page/8
# Juancho Hernangomez, TOR :7.71
# Reggie Bullock, DAL :7.71
# Austin Rivers, MIN :7.50
# Ziaire Williams, MEM :7.47
# Max Christie, LAL :7.44
# Juan Toscano-Anderson, LAL/UTAH :7.29
# Bryce McGowens, CHA :7.26
# Amir Coffey, LAC :7.12
# JT Thor, CHA :7.10
# Wesley Matthews, MIL :7.02
# Justin Holiday, ATL/DAL :6.69
# James Bouknight, CHA :6.30
# Caleb Houstan, ORL :6.29
# P.J. Tucker, PHI :5.73
# Daishen Nix, HOU :5.35
# Frank Ntilikina, DAL :5.28
# Blake Wesley, SA :3.58
# wait time : 5
